# %%
import numpy as np
import pandas as pd

# %% [markdown]
# pd panda frame , read_csv reading CSV file

# %%
df = pd.read_csv("mckinsey.csv")

# %%
df.head()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.head(10)
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106
# 5  Afghanistan  1977    14880372      Asia    38.438  786.113360
# 6  Afghanistan  1982    12881816      Asia    39.854  978.011439
# 7  Afghanistan  1987    13867957      Asia    40.822  852.395945
# 8  Afghanistan  1992    16317921      Asia    41.674  649.341395
# 9  Afghanistan  1997    22227415      Asia    41.763  635.341351

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.tail()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 1699  Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700  Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701  Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702  Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703  Zimbabwe  2007    12311143    Africa    43.487  469.709298

# %%
df.tail(7)
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 1697  Zimbabwe  1977     6642107    Africa    57.674  685.587682
# 1698  Zimbabwe  1982     7636524    Africa    60.363  788.855041
# 1699  Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700  Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701  Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702  Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703  Zimbabwe  2007    12311143    Africa    43.487  469.709298

# %%
df.shape
# Out:
# (1704, 6)

# %%
df["country"]
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
#            ...
# 1699       Zimbabwe
# 1700       Zimbabwe
# 1701       Zimbabwe
# 1702       Zimbabwe
# 1703       Zimbabwe
# Name: country, Length: 1704, dtype: object

# %%
type(df["country"])
# Out:
# pandas.core.series.Series

# %%
df.head()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   country     1704 non-null   object
#  1   year        1704 non-null   int64
#  2   population  1704 non-null   int64
#  3   continent   1704 non-null   object
#  4   life_exp    1704 non-null   float64
#  5   gdp_cap     1704 non-null   float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 80.0+ KB

# %%
#     country	  year	population	continent	life_exp	gdp_cap
# 0	Afghanistan	1952	8425333	    Asia	    28.801	  779.445314
# 1	Afghanistan	1957	9240934	    Asia	    30.332	  820.853030
# 2	Afghanistan	1962	102267083	  Asia	    31.997	  853.100710

# %%
#row-oriented appraoch

sample_df = pd.DataFrame(
              [['Afghanistan',1952, 8425333, 'Asia', 28.801, 779.445314 ],
              ['Afghanistan',1957, 9240934, 'Asia', 30.332, 820.853030 ],
              ['Afghanistan',1962, 102267083, 'Asia', 31.997, 853.100710 ]],

             columns=['country','year','population','continent','life_exp','gdp_cap']
    )

# %%
sample_df
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962   102267083      Asia    31.997  853.100710

# %%
#column-oriented appraoch


df2 = pd.DataFrame(
              {'country':['Afghanistan', 'Afghanistan'],
               'year':[1952,1957],
              'population':[842533, 9240934],
               'continent':['Asia', 'Asia'],
              'life_exp':[28.801, 30.332],
               'gdp_cap':[779.445314, 820.853030]
               }
    )

# %%
df2
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952      842533      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030

# %%
df.head()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
df.columns
# Out:
# Index(['country', 'year', 'population', 'continent', 'life_exp', 'gdp_cap'], dtype='object')

# %%
df.columns[0]
# Out:
# 'country'

# %%
df.columns[4]
# Out:
# 'life_exp'

# %%
df["country"]
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
#            ...
# 1699       Zimbabwe
# 1700       Zimbabwe
# 1701       Zimbabwe
# 1702       Zimbabwe
# 1703       Zimbabwe
# Name: country, Length: 1704, dtype: object

# %%
#syntax-2 : works but we dont use this in industry
df.country
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
#            ...
# 1699       Zimbabwe
# 1700       Zimbabwe
# 1701       Zimbabwe
# 1702       Zimbabwe
# 1703       Zimbabwe
# Name: country, Length: 1704, dtype: object

# %%
df2 = df[ ["year", "country"] ]

# %%
df2.head()
# Out:
#    year      country
# 0  1952  Afghanistan
# 1  1957  Afghanistan
# 2  1962  Afghanistan
# 3  1967  Afghanistan
# 4  1972  Afghanistan

# %%
#basic operations on column

# %%
unique_country = df["country"].unique() #all the unique values in a column

# %%
unique_country
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'Angola', 'Argentina',
#        'Australia', 'Austria', 'Bahrain', 'Bangladesh', 'Belgium',
#        'Benin', 'Bolivia', 'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'Bulgaria', 'Burkina Faso', 'Burundi', 'Cambodia', 'Cameroon',
#        'Canada', 'Central African Republic', 'Chad', 'Chile', 'China',
#        'Colombia', 'Comoros', 'Congo, Dem. Rep.', 'Congo, Rep.',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Czech Republic',
#        'Denmark', 'Djibouti', 'Dominican Republic', 'Ecuador', 'Egypt',
#        'El Salvador', 'Equatorial Guinea', 'Eritrea', 'Ethiopia',
#        'Finland', 'France', 'Gabon', 'Gambia', 'Germany', 'Ghana',
#        'Greece', 'Guatemala', 'Guinea', 'Guinea-Bissau', 'Haiti',
#        'Honduras', 'Hong Kong, China', 'Hungary', 'Iceland', 'India',
#        'Indonesia', 'Iran', 'Iraq', 'Ireland', 'Israel', 'Italy',
#        'Jamaica', 'Japan', 'Jordan', 'Kenya', 'Korea, Dem. Rep.',
# ...

# %% [markdown]
# nunique will count of unique columns in the column

# %%
count_unique = df["country"].nunique()

# %%
count_unique
# Out:
# 142

# %% [markdown]
# Value_counts() It will give every unique value how many rows are there in column

# %%
df["country"].value_counts()
# Out:
# Afghanistan          12
# Pakistan             12
# New Zealand          12
# Nicaragua            12
# Niger                12
#                      ..
# Eritrea              12
# Equatorial Guinea    12
# El Salvador          12
# Egypt                12
# Zimbabwe             12
# Name: country, Length: 142, dtype: int64

# %%
df["continent"].value_counts()
# Out:
# Africa      624
# Asia        396
# Europe      360
# Americas    300
# Oceania      24
# Name: continent, dtype: int64

# %%
#rename a column

# %%
df.head()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %% [markdown]
# Here Rename was not applied because the axis of was appling to axis= 0 Hence there are no columns in axis 0 column name of population and country

# %%
df.rename(
    {"population" : "Population",
     "country" : "Country"}
)
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %% [markdown]
# Here columns are in axis = 1  so it is applied. Hence columns are are changed

# %%
df.rename(
    {"population" : "Population",
     "country" : "Country"},

    axis = 1
)
# Out:
#           Country  year  Population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %% [markdown]
# About df is not modfied. It was returning only the modified data of the dataframe. Below we see dataframe country and population are still same.

# %%
df.head()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %% [markdown]
# This is one way to modify data. and save the in different datafame.

# %%
new_df = df.rename(
    {"population" : "Population",
     "country" : "Country"},

    axis = 1
)

# %%
new_df
# Out:
#           Country  year  Population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.head()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %% [markdown]
# To make changes in same dataframe we should apply inplace = True.
# This will make the changes in existing dataframe.

# %%
df.rename(
    {"population" : "Population",
     "country" : "Country"},

    axis = 1,
    inplace = True
)

# %% [markdown]
# Below we see the changes has applied

# %%
df.head()
# Out:
#        Country  year  Population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
#delete a column

# %%
df.drop("continent" , axis = 1)
# Out:
#           Country  year  Population  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333    28.801  779.445314
# 1     Afghanistan  1957     9240934    30.332  820.853030
# 2     Afghanistan  1962    10267083    31.997  853.100710
# 3     Afghanistan  1967    11537966    34.020  836.197138
# 4     Afghanistan  1972    13079460    36.088  739.981106
# ...           ...   ...         ...       ...         ...
# 1699     Zimbabwe  1987     9216418    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    43.487  469.709298
#
# [1704 rows x 5 columns]

# %% [markdown]
# We have dropped the column above but we do not see the columns changes in existing df.

# %%
df.head()
# Out:
#        Country  year  Population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
df.drop("continent" , axis = 1, inplace = True)

# %% [markdown]
# Applied inplace = True  , Now same dataframe is modifeid.

# %%
df.head()
# Out:
#        Country  year  Population  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333    28.801  779.445314
# 1  Afghanistan  1957     9240934    30.332  820.853030
# 2  Afghanistan  1962    10267083    31.997  853.100710
# 3  Afghanistan  1967    11537966    34.020  836.197138
# 4  Afghanistan  1972    13079460    36.088  739.981106

# %%
new_df.head()
# Out:
#        Country  year  Population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
#appraoch2

new_df.drop(columns = ["continent"])
# Out:
#           Country  year  Population  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333    28.801  779.445314
# 1     Afghanistan  1957     9240934    30.332  820.853030
# 2     Afghanistan  1962    10267083    31.997  853.100710
# 3     Afghanistan  1967    11537966    34.020  836.197138
# 4     Afghanistan  1972    13079460    36.088  739.981106
# ...           ...   ...         ...       ...         ...
# 1699     Zimbabwe  1987     9216418    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    43.487  469.709298
#
# [1704 rows x 5 columns]

# %%
new_df.drop(columns = ["continent"], inplace = True)

# %%
new_df.head()
# Out:
#        Country  year  Population  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333    28.801  779.445314
# 1  Afghanistan  1957     9240934    30.332  820.853030
# 2  Afghanistan  1962    10267083    31.997  853.100710
# 3  Afghanistan  1967    11537966    34.020  836.197138
# 4  Afghanistan  1972    13079460    36.088  739.981106

# %%
new_df.drop(columns = ["life_exp", "year"], inplace = True)

# %%
new_df.head()
# Out:
#        Country  Population     gdp_cap
# 0  Afghanistan     8425333  779.445314
# 1  Afghanistan     9240934  820.853030
# 2  Afghanistan    10267083  853.100710
# 3  Afghanistan    11537966  836.197138
# 4  Afghanistan    13079460  739.981106

# %%
#creating a new column

# %%
df.head()
# Out:
#        Country  year  Population  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333    28.801  779.445314
# 1  Afghanistan  1957     9240934    30.332  820.853030
# 2  Afghanistan  1962    10267083    31.997  853.100710
# 3  Afghanistan  1967    11537966    34.020  836.197138
# 4  Afghanistan  1972    13079460    36.088  739.981106

# %%
df["new_col"] = df["year"] + 7

# %% [markdown]
# New column is created , every row of year is added 7 . No need to write loop.

# %%
df.head()
# Out:
#        Country  year  Population  life_exp     gdp_cap  new_col
# 0  Afghanistan  1952     8425333    28.801  779.445314     1959
# 1  Afghanistan  1957     9240934    30.332  820.853030     1964
# 2  Afghanistan  1962    10267083    31.997  853.100710     1969
# 3  Afghanistan  1967    11537966    34.020  836.197138     1974
# 4  Afghanistan  1972    13079460    36.088  739.981106     1979

# %%
df["gdp"] = df["gdp_cap"]*df["Population"]

# %%
df.head()
# Out:
#        Country  year  Population  life_exp     gdp_cap  new_col           gdp
# 0  Afghanistan  1952     8425333    28.801  779.445314     1959  6.567086e+09
# 1  Afghanistan  1957     9240934    30.332  820.853030     1964  7.585449e+09
# 2  Afghanistan  1962    10267083    31.997  853.100710     1969  8.758856e+09
# 3  Afghanistan  1967    11537966    34.020  836.197138     1974  9.648014e+09
# 4  Afghanistan  1972    13079460    36.088  739.981106     1979  9.678553e+09

# %% [markdown]
# Createting new column df["column name "] = [list of columns]

# %%
df["new"] = [ i+3 for i in range(1704)]

# %%
df
# Out:
#           Country  year  Population  life_exp     gdp_cap  new_col  \
# 0     Afghanistan  1952     8425333    28.801  779.445314     1959
# 1     Afghanistan  1957     9240934    30.332  820.853030     1964
# 2     Afghanistan  1962    10267083    31.997  853.100710     1969
# 3     Afghanistan  1967    11537966    34.020  836.197138     1974
# 4     Afghanistan  1972    13079460    36.088  739.981106     1979
# ...           ...   ...         ...       ...         ...      ...
# 1699     Zimbabwe  1987     9216418    62.351  706.157306     1994
# 1700     Zimbabwe  1992    10704340    60.377  693.420786     1999
# 1701     Zimbabwe  1997    11404948    46.809  792.449960     2004
# 1702     Zimbabwe  2002    11926563    39.989  672.038623     2009
# 1703     Zimbabwe  2007    12311143    43.487  469.709298     2014
#
#                gdp   new
# 0     6.567086e+09     3
# 1     7.585449e+09     4
# 2     8.758856e+09     5
# 3     9.648014e+09     6
# 4     9.678553e+09     7
# ...

# %% [markdown]
# Drop mutiple columns permenently without creating new column

# %%
df.drop(columns = ["new_col", "gdp", "new"], inplace = True)

# %%
df.head()
# Out:
#        Country  year  Population  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333    28.801  779.445314
# 1  Afghanistan  1957     9240934    30.332  820.853030
# 2  Afghanistan  1962    10267083    31.997  853.100710
# 3  Afghanistan  1967    11537966    34.020  836.197138
# 4  Afghanistan  1972    13079460    36.088  739.981106

# %%
#dataframe indexing

# %%
df.head()
# Out:
#        Country  year  Population  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333    28.801  779.445314
# 1  Afghanistan  1957     9240934    30.332  820.853030
# 2  Afghanistan  1962    10267083    31.997  853.100710
# 3  Afghanistan  1967    11537966    34.020  836.197138
# 4  Afghanistan  1972    13079460    36.088  739.981106

# %% [markdown]
# list of all the column name df.columns

# %%
df.columns
# Out:
# Index(['Country', 'year', 'Population', 'life_exp', 'gdp_cap'], dtype='object')

# %% [markdown]
# Index. values numpy array for axis 0

# %%
df.index.values
# Out:
# array([   0,    1,    2, ..., 1701, 1702, 1703])

# %%
df.index = [ i+3 for i in range(1704)]

# %%
df.head()
# Out:
#        Country  year  Population  life_exp     gdp_cap
# 3  Afghanistan  1952     8425333    28.801  779.445314
# 4  Afghanistan  1957     9240934    30.332  820.853030
# 5  Afghanistan  1962    10267083    31.997  853.100710
# 6  Afghanistan  1967    11537966    34.020  836.197138
# 7  Afghanistan  1972    13079460    36.088  739.981106

# %%
'''
Implicit index --> starts from 0 --> iloc
Explicit index --> whatever is visible --> loc
It can be anything float, int , string object
'''
# Out:
# '\nImplicit index --> 0 --> iloc\nExplicit index --> whatever is visible --> loc\n'

# %%
df.head()
# Out:
#        Country  year  Population  life_exp     gdp_cap
# 3  Afghanistan  1952     8425333    28.801  779.445314
# 4  Afghanistan  1957     9240934    30.332  820.853030
# 5  Afghanistan  1962    10267083    31.997  853.100710
# 6  Afghanistan  1967    11537966    34.020  836.197138
# 7  Afghanistan  1972    13079460    36.088  739.981106

# %% [markdown]
# Excplicit -> it has given me the first row 3

# %%
df.loc[3]
# Out:
# Country       Afghanistan
# year                 1952
# Population        8425333
# life_exp           28.801
# gdp_cap        779.445314
# Name: 3, dtype: object

# %% [markdown]
# it has given me then row details 5

# %%
df.loc[5]
# Out:
# Country       Afghanistan
# year                 1962
# Population       10267083
# life_exp           31.997
# gdp_cap         853.10071
# Name: 5, dtype: object

# %% [markdown]
# This is implicit index

# %%
df.iloc[0]
# Out:
# Country       Afghanistan
# year                 1952
# Population        8425333
# life_exp           28.801
# gdp_cap        779.445314
# Name: 3, dtype: object

# %% [markdown]
# Recall List slicing concept

# %%
df.head()
# Out:
#        Country  year  Population  life_exp     gdp_cap
# 3  Afghanistan  1952     8425333    28.801  779.445314
# 4  Afghanistan  1957     9240934    30.332  820.853030
# 5  Afghanistan  1962    10267083    31.997  853.100710
# 6  Afghanistan  1967    11537966    34.020  836.197138
# 7  Afghanistan  1972    13079460    36.088  739.981106

# %% [markdown]
# End is inclusive in loc 3 to 6 columns are present

# %%
df.loc[3:6] #end is inclusive in loc
# Out:
#        Country  year  Population  life_exp     gdp_cap
# 3  Afghanistan  1952     8425333    28.801  779.445314
# 4  Afghanistan  1957     9240934    30.332  820.853030
# 5  Afghanistan  1962    10267083    31.997  853.100710
# 6  Afghanistan  1967    11537966    34.020  836.197138

# %% [markdown]
# End column is not included. 0,1,2,3 3 is not presnt which is 6

# %%
df.iloc[0:3]
# Out:
#        Country  year  Population  life_exp     gdp_cap
# 3  Afghanistan  1952     8425333    28.801  779.445314
# 4  Afghanistan  1957     9240934    30.332  820.853030
# 5  Afghanistan  1962    10267083    31.997  853.100710

# %%
df.head(10)
# Out:
#         Country  year  Population  life_exp     gdp_cap
# 3   Afghanistan  1952     8425333    28.801  779.445314
# 4   Afghanistan  1957     9240934    30.332  820.853030
# 5   Afghanistan  1962    10267083    31.997  853.100710
# 6   Afghanistan  1967    11537966    34.020  836.197138
# 7   Afghanistan  1972    13079460    36.088  739.981106
# 8   Afghanistan  1977    14880372    38.438  786.113360
# 9   Afghanistan  1982    12881816    39.854  978.011439
# 10  Afghanistan  1987    13867957    40.822  852.395945
# 11  Afghanistan  1992    16317921    41.674  649.341395
# 12  Afghanistan  1997    22227415    41.763  635.341351

# %%
df.loc[5:8]
# Out:
#        Country  year  Population  life_exp     gdp_cap
# 5  Afghanistan  1962    10267083    31.997  853.100710
# 6  Afghanistan  1967    11537966    34.020  836.197138
# 7  Afghanistan  1972    13079460    36.088  739.981106
# 8  Afghanistan  1977    14880372    38.438  786.113360

# %%
df.iloc[5:8]
# Out:
#         Country  year  Population  life_exp     gdp_cap
# 8   Afghanistan  1977    14880372    38.438  786.113360
# 9   Afghanistan  1982    12881816    39.854  978.011439
# 10  Afghanistan  1987    13867957    40.822  852.395945

# %%
df.head()
# Out:
#        Country  year  Population  life_exp     gdp_cap
# 3  Afghanistan  1952     8425333    28.801  779.445314
# 4  Afghanistan  1957     9240934    30.332  820.853030
# 5  Afghanistan  1962    10267083    31.997  853.100710
# 6  Afghanistan  1967    11537966    34.020  836.197138
# 7  Afghanistan  1972    13079460    36.088  739.981106

# %%
df.iloc[[2,4]]
# Out:
#        Country  year  Population  life_exp     gdp_cap
# 5  Afghanistan  1962    10267083    31.997  853.100710
# 7  Afghanistan  1972    13079460    36.088  739.981106

# %%
df.iloc[-1]
# Out:
# Country         Zimbabwe
# year                2007
# Population      12311143
# life_exp          43.487
# gdp_cap       469.709298
# Name: 1706, dtype: object

# %%
df.tail()
# Out:
#        Country  year  Population  life_exp     gdp_cap
# 1702  Zimbabwe  1987     9216418    62.351  706.157306
# 1703  Zimbabwe  1992    10704340    60.377  693.420786
# 1704  Zimbabwe  1997    11404948    46.809  792.449960
# 1705  Zimbabwe  2002    11926563    39.989  672.038623
# 1706  Zimbabwe  2007    12311143    43.487  469.709298

# %%
df.loc[-1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: -1
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df.head()
# Out:
#        Country  year  Population  life_exp     gdp_cap
# 3  Afghanistan  1952     8425333    28.801  779.445314
# 4  Afghanistan  1957     9240934    30.332  820.853030
# 5  Afghanistan  1962    10267083    31.997  853.100710
# 6  Afghanistan  1967    11537966    34.020  836.197138
# 7  Afghanistan  1972    13079460    36.088  739.981106

# %%
temp = df.set_index("Country")

# %%
temp.head()
# Out:
#              year  Population  life_exp     gdp_cap
# Country
# Afghanistan  1952     8425333    28.801  779.445314
# Afghanistan  1957     9240934    30.332  820.853030
# Afghanistan  1962    10267083    31.997  853.100710
# Afghanistan  1967    11537966    34.020  836.197138
# Afghanistan  1972    13079460    36.088  739.981106

# %%
temp.loc["Afghanistan"]
# Out:
#              year  Population  life_exp     gdp_cap
# Country
# Afghanistan  1952     8425333    28.801  779.445314
# Afghanistan  1957     9240934    30.332  820.853030
# Afghanistan  1962    10267083    31.997  853.100710
# Afghanistan  1967    11537966    34.020  836.197138
# Afghanistan  1972    13079460    36.088  739.981106
# Afghanistan  1977    14880372    38.438  786.113360
# Afghanistan  1982    12881816    39.854  978.011439
# Afghanistan  1987    13867957    40.822  852.395945
# Afghanistan  1992    16317921    41.674  649.341395
# Afghanistan  1997    22227415    41.763  635.341351
# Afghanistan  2002    25268405    42.129  726.734055
# Afghanistan  2007    31889923    43.828  974.580338

# %%
df.head()
# Out:
#        Country  year  Population  life_exp     gdp_cap
# 3  Afghanistan  1952     8425333    28.801  779.445314
# 4  Afghanistan  1957     9240934    30.332  820.853030
# 5  Afghanistan  1962    10267083    31.997  853.100710
# 6  Afghanistan  1967    11537966    34.020  836.197138
# 7  Afghanistan  1972    13079460    36.088  739.981106

# %% [markdown]
# Some times when we do joining or manuplicating the data or doing grouby, and our dataframe numbering maybe miss matched. or started the count differently.
# we can use reset index, orginal row cnumbers will create new column as index and starts from 0 with the fresh count.

# %%
df.reset_index()
# Out:
#       index      Country  year  Population  life_exp     gdp_cap
# 0         3  Afghanistan  1952     8425333    28.801  779.445314
# 1         4  Afghanistan  1957     9240934    30.332  820.853030
# 2         5  Afghanistan  1962    10267083    31.997  853.100710
# 3         6  Afghanistan  1967    11537966    34.020  836.197138
# 4         7  Afghanistan  1972    13079460    36.088  739.981106
# ...     ...          ...   ...         ...       ...         ...
# 1699   1702     Zimbabwe  1987     9216418    62.351  706.157306
# 1700   1703     Zimbabwe  1992    10704340    60.377  693.420786
# 1701   1704     Zimbabwe  1997    11404948    46.809  792.449960
# 1702   1705     Zimbabwe  2002    11926563    39.989  672.038623
# 1703   1706     Zimbabwe  2007    12311143    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.reset_index(drop = True)
# Out:
#           Country  year  Population  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333    28.801  779.445314
# 1     Afghanistan  1957     9240934    30.332  820.853030
# 2     Afghanistan  1962    10267083    31.997  853.100710
# 3     Afghanistan  1967    11537966    34.020  836.197138
# 4     Afghanistan  1972    13079460    36.088  739.981106
# ...           ...   ...         ...       ...         ...
# 1699     Zimbabwe  1987     9216418    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    43.487  469.709298
#
# [1704 rows x 5 columns]

# %%
df.head()
# Out:
#        Country  year  Population  life_exp     gdp_cap
# 3  Afghanistan  1952     8425333    28.801  779.445314
# 4  Afghanistan  1957     9240934    30.332  820.853030
# 5  Afghanistan  1962    10267083    31.997  853.100710
# 6  Afghanistan  1967    11537966    34.020  836.197138
# 7  Afghanistan  1972    13079460    36.088  739.981106

# %%
df.reset_index(drop = True, inplace =True)

# %%
df.head()
# Out:
#        Country  year  Population  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333    28.801  779.445314
# 1  Afghanistan  1957     9240934    30.332  820.853030
# 2  Afghanistan  1962    10267083    31.997  853.100710
# 3  Afghanistan  1967    11537966    34.020  836.197138
# 4  Afghanistan  1972    13079460    36.088  739.981106

# %% [markdown]
# Doubts
